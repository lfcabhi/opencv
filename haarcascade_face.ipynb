# %% [markdown]
# <a href="https://colab.research.google.com/github/lfcabhi/opencv/blob/master/haarcascade_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from google.colab import files
file= files.upload()
# Out:
#      <input type="file" id="files-f465a3bf-954d-4b8c-b013-d401b9fa7d04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f465a3bf-954d-4b8c-b013-d401b9fa7d04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_frontalface_default.xml to haarcascade_frontalface_default.xml
# Saving img_2.jpeg to img_2 (1).jpeg
# Saving Nariz.xml to Nariz.xml

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
img=cv2.imread('img_2.jpeg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.06, 3)
print(faces)
# Out:
# [[ 46  88 307 307]
#  [454 196 242 242]]

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (25, 255, 25), 3)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
plt.grid(None)
plt.xticks(ticks=None)
plt.yticks(ticks=None)
imgplot=plt.imshow(img)
